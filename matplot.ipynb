# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Vangala/Python-new/blob/Module-4/matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, linewidth = 4.8)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,9])
ypoints = np.array([4,19])

plt.plot(xpoints, ypoints,color='black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, 'o' ,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5,10,67,98,54])

plt.plot(ypoints, color='black')
plt.show()

# %% [markdown]
# Marker

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='o' ,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='*' ,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='D' ,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, 'o:r' ,color='green')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='o' ,ms = 28)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='o' ,ms = 28, mec = 'g')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints, marker='o' ,ms = 28, mfc = 'g')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Line

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,linestyle='dotted')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(['Clad', 'IT','Programming','English','EVPR','Pysics'])
y = np.array([83,80,60,95,100,52])
plt.plot(x, y, ls='--', color='red')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,linestyle=':', color='black')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,linestyle='None')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,linestyle='dashdot')
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints,linestyle='dotted', linewidth= 20)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints1 = np.array([83,80,60,95,100,52])
ypoints2 = np.array([90,87,98,99,67,89])
plt.plot(xpoints, ypoints1)
plt.plot(xpoints, ypoints2)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %% [markdown]
# Labels

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.plot(xpoints, ypoints)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1)
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1, loc='left')
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.show()

# %% [markdown]
# Grid

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1)
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1)
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.grid(axis= 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1)
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])
font1 = {'family':'serif','color':'#2c4f04','size':20}
font2 = {'family':'serif','color':'#08396e','size':15}
plt.plot(xpoints, ypoints)
plt.title("Grades",fontdict=font1)
plt.xlabel("Course", fontdict=font2)
plt.ylabel("Marks", fontdict=font2)
plt.grid(color='#2c4f04', linestyle='dotted', linewidth= 2.5)
plt.show()

# %% [markdown]
# Subplots

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 5, 7])
y = np.array([31, 84, 98, 177])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 5, 7])
y = np.array([10, 40, 80, 120])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 5, 7])
y = np.array([31, 84, 98, 177])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title('1')

#plot 2:
x = np.array([0, 1, 5, 7])
y = np.array([10, 40, 80, 120])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title('2')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 5, 7])
y = np.array([31, 84, 98, 177])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title('1')

#plot 2:
x = np.array([0, 1, 5, 7])
y = np.array([10, 40, 80, 120])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title('2')

plt.suptitle("Graphs")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title('1')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title('2')

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.title('3')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title('4')

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title('5')

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title('6')

plt.suptitle('Graphs')
plt.show()

# %% [markdown]
# Scatter

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1,2,3,4,5,6,7])
y = np.array([95,94,96,98,92,99,45])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color='green')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = '#8a3054')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#e8bc1c')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","#75746f","black","orange","#752e30","beige","brown","gray","#e8bc1c","#09057d"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='inferno')
plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, s=sizes, cmap='coolwarm')
plt.colorbar()
plt.show()

# %% [markdown]
# Bars

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.bar(xpoints, ypoints)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.barh(xpoints, ypoints)
plt.ylabel("Course")
plt.xlabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.barh(xpoints, ypoints, color='#458f8c')
plt.ylabel("Course")
plt.xlabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.bar(xpoints, ypoints, width= 0.1)
plt.xlabel("Course")
plt.ylabel("Marks")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(['Clad','IT','Programming','English','Evpr','Physics'])
ypoints = np.array([83,80,60,95,100,52])

plt.barh(xpoints, ypoints, color='#458f8c', height=0.1)
plt.ylabel("Course")
plt.xlabel("Marks")
plt.show()

# %% [markdown]
# Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(150, 5, 69)
plt.hist(x, color='#021524')
plt.show()

# %% [markdown]
# Pie charts

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
plt.pie(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
plt.pie(x, labels=y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
plt.pie(x, labels=y, startangle= 180)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
z= [0.5,0,0,0,0,0]
plt.pie(x, labels=y, explode=z)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
z= [0.5,0,0,0,0,0]
plt.pie(x, labels=y, shadow=True, explode=z)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
cl= ['#3b5673', '#0256ad', '#4f95db', '#077af0', '#b0d3f7', '#021524']
z= [0.5,0,0,0,0,0]
plt.pie(x, labels=y, shadow=True, colors=cl, explode=z)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
cl= ['#3b5673', '#0256ad', '#4f95db', '#077af0', '#b0d3f7', '#021524']
z= [0.5,0,0,0,0,0]
plt.pie(x, labels=y, shadow=True, colors=cl, explode=z)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
cl= ['#3b5673', '#0256ad', '#4f95db', '#077af0', '#b0d3f7', '#021524']
plt.pie(x, labels=y, shadow=True, colors=cl)
plt.legend(title= 'Courses:')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
cl= ['#3b5673', '#0256ad', '#4f95db', '#077af0', '#b0d3f7', '#021524']
z= [0.5,0,0,0,0,0]
plt.pie(x, labels=y, shadow=True, colors=cl, explode=z)
plt.legend(title= 'Courses:')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([83,80,60,95,100,52])
y= ['Clad', 'IT', 'Programming', 'English', 'EVPR', 'Physics']
cl= ['#3b5673', '#0256ad', '#4f95db', '#077af0', '#b0d3f7', '#021524']
z= [0.5,0.2,0.2,0.5,0.2,0.2]
plt.pie(x, labels=y, shadow=True, colors=cl, explode=z)
plt.legend(title= 'Courses:')
plt.show()
